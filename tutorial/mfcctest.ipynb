# %%
from librosa.feature import mfcc

# %%
from scipy.io import wavfile

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
sr,x = wavfile.read("../feature/A11_0.wav")

# %%
# Out:
# 32768

# %%
res = mfcc(x/np.max(np.abs(x)),sr=sr,n_mfcc=200)

# %%
plt.imshow(res)
