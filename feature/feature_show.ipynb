# %%
from mel_feature import *
from matplotlib import pyplot as plt
from scipy.io import wavfile

# %%
_,x = wavfile.read("A11_1.wav")
plt.plot(x)

# %%
plt.imshow(MelFeature().mfcc(x))

# %%
plt.imshow(MelFeature2().mfcc(x))

# %%
plt.imshow(MelFeature3().mfcc(x))

# %%
plt.imshow(MelFeature4().mfcc(x))
# Out:
# (707, 200)

# %%
plt.imshow(MelFeature5().mfcc(x))
